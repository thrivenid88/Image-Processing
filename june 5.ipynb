# %%
#Import required Image library
from PIL import Image, ImageFilter

#Open existing image
OriImage = Image.open('C:/Users/User/Image Processing 2023/Program Files/cake.jfif')
OriImage.show()

blurImage = OriImage.filter(ImageFilter.BLUR)
blurImage.show()
blurImage
# Out:
# <PIL.Image.Image image mode=RGB size=277x182>

# %%
#Import required Image library
from PIL import Image
 
#Open existing image
OriImage = Image.open('C:/Users/User/Image Processing 2023/Program Files/cake.jfif')
OriImage.show()

#Applying BoxBlur filter
boxImage = OriImage.filter(ImageFilter.BoxBlur(1.5))
boxImage.show()
boxImage
# Out:
# <PIL.Image.Image image mode=RGB size=277x182>

# %%
#Import required Image library
from PIL import Image, ImageFilter

#Open existing image
OriImage = Image.open('C:/Users/User/Image Processing 2023/Program Files/cake.jfif')
OriImage.show()

#Applying GaussianBlur filter
gaussImage = OriImage.filter(ImageFilter.GaussianBlur(5))
gaussImage.show()
gaussImage
# Out:
# <PIL.Image.Image image mode=RGB size=277x182>

# %%
from PIL import Image, ImageFilter
im = Image.open('C:/Users/User/Image Processing 2023/Program Files/cake.jfif')
im1 = im.filter(ImageFilter.MedianFilter(size = 7))
im.show()
im1
# Out:
# <PIL.Image.Image image mode=RGB size=277x182>

# %%
import cv2
import numpy as np
  
  # Read the image
img_noisy1 = cv2.imread('C:/Users/User/Image Processing 2023/Program Files/cake.jfif',0)
  
# Obtain the number of rows and columns 
# of the image
m, n = img_noisy1.shape
   
# Traverse the image. For every 3X3 area, 
# find the median of the pixels and
# replace the center pixel by the median
img_new1 = np.zeros([m, n])
  
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = [img_noisy1[i-1, j-1],
               img_noisy1[i-1, j],
               img_noisy1[i-1, j + 1],
               img_noisy1[i, j-1],
               img_noisy1[i, j],
               img_noisy1[i, j + 1],
               img_noisy1[i + 1, j-1],
               img_noisy1[i + 1, j],
               img_noisy1[i + 1, j + 1]]
          
        temp = sorted(temp)
        img_new1[i, j]= temp[4]
img_new1 = img_new1.astype(np.uint8)
cv2.imwrite('new_median_filtered.png', img_new1)
cv2.waitKey()
cv2.destroyAllWindows()
