# %%
#drawing on a image
import numpy as np
import cv2
img=cv2.imread("C:/Users/User/Downloads/nat.jpg",1)
cv2.line(img,(400,20),(20,400),(255,255,255),3)
cv2.rectangle(img,(300,200),(500,400),(0,250,0),5)
cv2.circle(img,(80,80),55,(300,300,0),-1)
cv2.ellipse(img,(600,570),(80,280),5,0,360,(0,0,255),-1)
cv2.imshow("Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# repair damaged images=====error
import cv2
import matplotlib.pyplot as plt
damaged_image_path = "C:/Users/User/Desktop/paint.png"
damaged_image = cv2.imread(damaged_image_path)
mask_path = "mask.png"
mask = cv2.imread(mask_path, 0)
damaged_image = cv2.cvtColor(damaged_image, cv2.COLOR_BGR2RGB)
output1 = cv2.inpaint(damaged_image, mask, 1, cv2.INPAINT_TELEA)
output2 = cv2.inpaint(damaged_image, mask, 1, cv2.INPAINT_NS)
img = [damaged_image, mask, output1, output2]
titles = ['damaged image', 'mask', 'TELEA', 'NS']
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[i])
    plt.imshow(img[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9868/462625758.py in <module>
#       7 mask = cv2.imread(mask_path, 0)
#       8 damaged_image = cv2.cvtColor(damaged_image, cv2.COLOR_BGR2RGB)
# ----> 9 output1 = cv2.inpaint(damaged_image, mask, 1, cv2.INPAINT_TELEA)
#      10 output2 = cv2.inpaint(damaged_image, mask, 1, cv2.INPAINT_NS)
#      11 img = [damaged_image, mask, output1, output2]
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\core\src\array.cpp:2494: error: (-206:Bad flag (parameter or structure field)) Unrecognized or unsupported array type in function 'cvGetMat'

# %%
import cv2
import numpy as np


image = cv2.imread('C:/Users/User/Downloads/abraham.jpg')
cv2.imshow('Original Damaged Photo', image)
cv2.waitKey(0)

marked_damages = cv2.imread('C:/Users/User/Downloads/mask.jpg', 0)
cv2.imshow('Marked Damages', marked_damages)
cv2.waitKey(0)

ret, thresh1 = cv2.threshold(marked_damages, 254, 255, cv2.THRESH_BINARY)
cv2.imshow('Threshold Binary', thresh1)
cv2.waitKey(0)

kernel = np.ones((7,7), np.uint8)
mask = cv2.dilate(thresh1, kernel, iterations = 1)
cv2.imshow('Dilated Mask', mask)
cv2.imwrite("abraham_mask.png", mask)

cv2.waitKey(0)
restored = cv2.inpaint(image, mask, 3, cv2.INPAINT_TELEA)

cv2.imshow('Restored', restored)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
imgo = cv2.imread('C:/Users/User/Downloads/nat.jpg')


# Generate random Gaussian noise
mean = 10
stddev = 80
noise = np.zeros(img.shape, np.uint8)
cv2.randn(noise, mean, stddev)

# Add noise to image
noisy_img = cv2.add(img, noise)

# Save noisy image
plt.imshow(imgo)
plt.show()
plt.imshow(noise)
plt.show()

# %%
#noise image=adding
import matplotlib.pyplot as plt
from skimage.util import random_noise
img=plt.imread("C:/Users/User/Downloads/nn.jfif")
nature_image=random_noise(img)
plt.imshow(img)
plt.show()
plt.imshow(nature_image)
plt.show()

# %% [raw]
# import matplotlib.pyplot as plt
# from skimage.restoration import denoise_tv_chambolle
# img=plt.imread("C:/Users/User/Downloads/nn.jfif")
# nature_image=denoise_tv_chambolle(img)
# plt.imshow(img)
# plt.show()
# plt.imshow(nature_image)
# plt.show()

# %%
#
import matplotlib.pyplot as plt
from skimage.restoration import denoise_tv_chambolle
img=plt.imread("C:/Users/User/Downloads/nn.jfif")
nature_image=denoise_tv_chambolle(img)
plt.imshow(img)
plt.show()
plt.imshow(nature_image)
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage.restoration import denoise_bilateral
img=plt.imread("C:/Users/User/Downloads/nn.jfif")
nature_image=denoise_bilateral(img,multichannel=True)
plt.imshow(img)
plt.show()
plt.imshow(nature_image)
plt.show()
