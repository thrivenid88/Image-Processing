# %%
from PIL import Image
oi_Image=Image.open("orange.png")
rotate_image1=oi_Image.rotate(360)
rotate_image2=oi_Image.rotate(90)
rotate_image3=oi_Image.rotate(180)
rotate_image4=oi_Image.rotate(270)
rotate_image5=oi_Image.rotate(45)
rotate_image1.show()
rotate_image2.show()
rotate_image3.show()
rotate_image4.show()
rotate_image5.show()

# %%
import numpy as np
import cv2 as cv
img = cv.imread('orange.png', 0)
img_shrinked = cv.resize(img, (250, 200))
cv.imshow('img', img_shrinked)
img_enlarged = cv.resize(img_shrinked, None,fx=2.5, fy=2)
cv.imshow('img', img_enlarged)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# read the input image
img = cv2.imread("stra.jfif")
# convert from BGR to RGB so we can plot using matplotlib
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# disable x & y axis
plt.axis('off')
# show the image
plt.imshow(img)
plt.show()
# get the image shape
rows, cols, dim = img.shape
#transformation matrix for Scaling
M = np.float32([[1.5, 0  , 0],
                [0,   1.8, 0],
            	[0,   0,   1]])
# apply a perspective transformation to the image
scaled_img = cv2.warpPerspective(img,M,(cols*2,rows*2))
# disable x & y axis
plt.axis('off')
# show the resulting image
plt.imshow(scaled_img)
plt.show()
# save the resulting image to disk
plt.imsave("city_scaled.png", scaled_img)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# read the input image
img = cv2.imread("kivi.jfif")
# convert from BGR tonge RGB so we can plot using matplotlib
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# disable x & y axis
plt.axis('off')
# show the image
plt.imshow(img)
plt.show()
# get the image shape
rows, cols, dim = img.shape
# transformation matrix for translation
M = np.float32([[1, 0, 50],
                [0, 1, 50],
                [0, 0, 1]])
# apply a perspective transformation to the image
translated_img = cv2.warpPerspective(img, M, (cols, rows))
# disable x & y axis
plt.axis('off')
# show the resulting image
plt.imshow(translated_img)
plt.show()
# save the resulting image to disk
plt.imsave("kivi_translated.png", translated_img)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# read the input image
img = cv2.imread("f1.jfif")
# convert from BGR to RGB so we can plot using matplotlib
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# disable x & y axis
plt.axis('off')
# show the image
plt.imshow(img)
plt.show()
# get the image shape
rows, cols, dim = img.shape
#transformation matrix for Scaling
M = np.float32([[1.5, 0  , 0],
            	[0,   1.8, 0],
            	[0,   0,   1]])
# apply a perspective transformation to the image
scaled_img = cv2.warpPerspective(img,M,(cols*2,rows*2))
# disable x & y axis
plt.axis('off')
# show the resulting image
plt.imshow(scaled_img)
plt.show()
# save the resulting image to disk
plt.imsave("f1_scaled.jpg", scaled_img)

# %%
import cv2
from matplotlib import pyplot as plt
img=cv2.imread('f1.jfif')
cv2.imshow("image before upsamppling",img)
img=cv2.pyrUp(img)
cv2.imshow("upsamppling",img)
plt.imshow(img)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
img=cv2.imread('f1.jfif')
cv2.imshow("image before down samppling",img)
img=cv2.pyrDown(img)
cv2.imshow("downsampling",img)
plt.imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img1=cv2.imread("i1.jpg")
img2=cv2.imread("i2.jpg")
add=img1+img2
cv2.imshow("add",add)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Python program for adding
# images using OpenCV

# import OpenCV file
import cv2

# Read Image1
mountain = cv2.imread('s1.jfif', 1)

# Read image2
dog = cv2.imread('1.jfif', 1)

# Add the images
img = cv2.add(mountain,dog)

# Show the image
cv2.imshow('image', img)

# Wait for a key
cv2.waitKey(0)

# Distroy all the window open
cv2.distroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8932/1982669887.py in <module>
#      12
#      13 # Add the images
# ---> 14 img = cv2.add(mountain,dog)
#      15
#      16 # Show the image
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
import cv2
img1=cv2.imread("i3.jpg")
img2=cv2.imread("i4.jpg")
sub=img1-img2
cv2.imshow("sub",sub)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img1=cv2.imread("i3.jpg")
img2=cv2.imread("i4.jpg")
mul=img1*img2
cv2.imshow("mul",mul)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#bleding of image
import cv2
img1=cv2.imread('i3.jpg')
img2=cv2.imread('i4.jpg')
s1=cv2.addWeighted(img1,0.3,img2,0.7,0)
cv2.imshow('image',s1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img=cv2.imread('i1.jfif',0)
plt.hist(img.ravel(),256,[0,256])
plt.show()

equ=cv2.equalizeHist(img)
res=np.hstack((img,equ))
cv2.imshow('equalized image',res)
cv2.imwrite('equalised image.png',res)

plt.hist(res.ravel(),256,[0,256])
plt.show()
