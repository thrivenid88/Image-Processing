# %%
#image extraction
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread,imshow
image1=imread('C:/Users/User/Downloads/images.jfif')
imshow(image1)

# %%
image2=imread("C:/Users/User/Downloads/images.jfif",as_gray=True)
imshow(image2)

# %%
print(image1.shape)
print(image2.shape)
# Out:
# (177, 284, 3)
# (177, 284)

# %%
print(image1.size)
print(image2.size)
# Out:
# 150804
# 50268

# %%
pixel_features1=np.reshape(image1,(177*284*3))
pixel_features1.shape,pixel_features1
# Out:
# ((150804,), array([255, 255, 255, ...,  21,  27,   0], dtype=uint8))

# %%
from PIL import Image,ImageStat
im=Image.open("C:/Users/User/Downloads/images.jfif")
stat=ImageStat.Stat(im)
print(stat.var)
# Out:
# [10059.179187784159, 7424.507950590848, 12624.512363813115]

# %%
pixel_features2=np.reshape(image2,(177*284))
pixel_features2.shape,pixel_features2
# Out:
# ((50268,),
#  array([1.        , 1.        , 1.        , ..., 0.25625059, 0.18287176,
#         0.09324824]))
